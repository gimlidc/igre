# %%
# %load_ext autoreload
# %autoreload 1
import  scipy.io  as sio
import numpy as np
from src.data.phantom.materials import load_alma, load_firenze
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
alma = load_alma()

# %%
phantom = np.ones((3,3), dtype=int)

# %%
phantom

# %%
from src.models.ig_cnn import wavelength2rgb
import matplotlib.pyplot as plt
plt.imshow(
    wavelength2rgb(create_phantom(phantom, Material.ALMA)[:, :, :16]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-61e4b8c5b668> in <module>
#       2 import matplotlib.pyplot as plt
#       3 plt.imshow(
# ----> 4     wavelength2rgb(create_phantom(phantom, Material.ALMA)[:, :, :16]))
#       5
#
# NameError: name 'create_phantom' is not defined

# %%
import scipy.io as sio
import matplotlib.pyplot as plt
import glob
import numpy as np
vis = glob.glob('../data/raw/phantoms/TIF.8bit_norm.255/Ch*_VIS_*.tif')
nir = glob.glob('../data/raw/phantoms/TIF.8bit_norm.255/Ch*_NIR_*.tif')
mask = sio.loadmat('../data/raw/phantoms/bianco_mask.mat')['res_2d']

layers = [*vis, *nir]
x,y = plt.imread(layers[0]).shape
z = len(layers)

raw_img = np.zeros((x,y,z))
for i, l in enumerate(layers):
    raw_img[:,:,i] = plt.imread(l)

# %%
plt.imshow(
    wavelength2rgb(raw_img[:,:,:16]/255.0)
    )

# %%
raw_img.shape
# Out:
# (1400, 1200, 32)

# %%
plt.imshow(mask, cmap='gray')

# %%
for i in range(np.max(mask)+1):
    plt.imshow(mask == i)

# %%
plt.imshow((mask == 1), cmap='gray')

# %%
mask_multid = np.repeat(
        np.expand_dims(
           (mask == 1),
            axis=-1),
        repeats=32,
        axis=-1
    )

square = raw_img * mask_multid
plt.imshow(
    wavelength2rgb(
        square[:,:,:16]/255.0)
    )

# %%
np.repeat(, 1, 1, 16).shape
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-66-9a42d1c6ceb5> in <module>
# ----> 1 np.repeat((mask == 1), 1, 1, 16).shape
#
# <__array_function__ internals> in repeat(*args, **kwargs)
#
# TypeError: _repeat_dispatcher() takes from 2 to 3 positional arguments but 4 were given

# %%
(mask == 1).shape
# Out:
# (1400, 1200)

# %%
# Out:
# (1400, 1200, 16)
